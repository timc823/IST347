# %% [markdown]
# Name: Tim Chen
#
# Date: 2/1/2021

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Step 1: Load the Assignment#1_Part1_Motor_Insurance_Fraud.csv

# %%
df = pd.read_csv('/content/drive/MyDrive/IST347_Machine-Learning-in-Healthcare/Week_2/Assignment#1_Part1_Motor_Insurance_Fraud.csv')

# %% [markdown]
# Step 2:  Explore the dataset

# %% [markdown]
# •	Display the dataframe

# %%
df
# Out:
#       ID Insurance Type   ...  Claim Amount Received Fraud Flag
# 0      1              CI  ...                      0          1
# 1      2              CI  ...                  15028          0
# 2      3              CI  ...                    572          0
# 3      4              CI  ...                 270200          0
# 4      5              CI  ...                      0          1
# ..   ...             ...  ...                    ...        ...
# 495  496              CI  ...                      0          1
# 496  497              CI  ...                      0          1
# 497  498              CI  ...                  16763          0
# 498  499              CI  ...                 179448          0
# 499  500              CI  ...                      0          1
#
# [500 rows x 14 columns]

# %% [markdown]
# •	What are all the columns? What are their data types?

# %%
df.columns
# Out:
# Index(['ID', 'Insurance Type ', 'Income of Policy Holder', 'Marital Status',
#        'Num Claimants', 'Injury Type', 'Overnight Hospital Stay',
#        'Claim Amount', 'Total Claimed', 'Num Claims', 'Num Soft Tissue',
#        '% Soft Tissue', 'Claim Amount Received', 'Fraud Flag'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ID                           int64
# Insurance Type              object
# Income of Policy Holder      int64
# Marital Status              object
# Num Claimants                int64
# Injury Type                 object
# Overnight Hospital Stay     object
# Claim Amount                 int64
# Total Claimed                int64
# Num Claims                   int64
# Num Soft Tissue            float64
# % Soft Tissue              float64
# Claim Amount Received        int64
# Fraud Flag                   int64
# dtype: object

# %% [markdown]
# •	Pick any column and show it.

# %%
df.ID
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 495    496
# 496    497
# 497    498
# 498    499
# 499    500
# Name: ID, Length: 500, dtype: int64

# %% [markdown]
# •	Create new column “revenue” which is sum of “Num claims” and “Claim Amount Received”. Check to see if new column is there or not.

# %%
df['revenue'] = df['Num Claims'] + df['Claim Amount Received']
df.head()
# Out:
#    ID Insurance Type   ...  Fraud Flag revenue
# 0   1              CI  ...           1       2
# 1   2              CI  ...           0   15029
# 2   3              CI  ...           0     572
# 3   4              CI  ...           0  270200
# 4   5              CI  ...           1       0
#
# [5 rows x 15 columns]

# %% [markdown]
# •	Select any row and display that

# %%
df.iloc[0]
# Out:
# ID                                   1
# Insurance Type                      CI
# Income of Policy Holder              0
# Marital Status                     NaN
# Num Claimants                        2
# Injury Type                Soft Tissue
# Overnight Hospital Stay             No
# Claim Amount                      1625
# Total Claimed                     3250
# Num Claims                           2
# Num Soft Tissue                      2
# % Soft Tissue                        1
# Claim Amount Received                0
# Fraud Flag                           1
# revenue                              2
# Name: 0, dtype: object

# %% [markdown]
# Step 3: Identify missing attribute field(s). Which have missing values and how many? Propose a way to resolve these missing values for those attributes.

# %%
df.isna().sum()
# Out:
# ID                           0
# Insurance Type               0
# Income of Policy Holder      0
# Marital Status             330
# Num Claimants                0
# Injury Type                  0
# Overnight Hospital Stay      0
# Claim Amount                 0
# Total Claimed                0
# Num Claims                   0
# Num Soft Tissue             10
# % Soft Tissue                0
# Claim Amount Received        0
# Fraud Flag                   0
# revenue                      0
# dtype: int64

# %% [markdown]
# For the Num Soft Tissue, because it only has 10 missing values, I think I can replace those 10 cells with the median of Num Soft Tissue. However, for the Marital Status, it's almost 70% missing value. I think I can just drop the entire column.

# %% [markdown]
# Step4: Consider the attribute “Insurance Type”. Do you find it odd? How would you remove that attribute?
#
# Ans: Yes, all insurance types are the same.

# %%
df['Insurance Type '].unique()
# Out:
# array(['CI'], dtype=object)

# %%
df.drop(['Insurance Type '], axis =1,inplace=True)

# %% [markdown]
# Step 5: Explore how the attributes vary or relate to each other. Calculate and visualize correlations using correlation matrix

# %%
corr = df.corr()
plt.figure(figsize=(12,6))
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns, cmap='coolwarm')

# %% [markdown]
# Step6: Try to keep some and eliminate some attributes based on correlation matrix.

# %%
df.drop(columns= ['Claim Amount','% Soft Tissue','Total Claimed','Claim Amount Received'], inplace=True)

# %%
df.head()
# Out:
#    ID  Income of Policy Holder  ... Fraud Flag  revenue
# 0   1                        0  ...          1        2
# 1   2                        0  ...          0    15029
# 2   3                    54613  ...          0      572
# 3   4                        0  ...          0   270200
# 4   5                        0  ...          1        0
#
# [5 rows x 10 columns]

# %%
new_corr = df.corr()
plt.figure(figsize=(12,6))
sns.heatmap(new_corr, 
        xticklabels=new_corr.columns,
        yticklabels=new_corr.columns, cmap='coolwarm')

# %% [markdown]
# Step 7: Save your notebook and share it on canvas. Using text comments,  write briefly your observations and inferences.

# %% [markdown]
# From the above practice, I noticed that in the original data there were some columns are petter similar to others. Therefore I had the drop some columns to prevent the bias from high correlated columns. Although in this exercise we created by two columns added, so it also had high correlation with some columns from the original data. However, I end-up with keeping the revenue column because in general this is the only column present the revenue of the data, and I will keep it if it's the only column that shows the revenue.
