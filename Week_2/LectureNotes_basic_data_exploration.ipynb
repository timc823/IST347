# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv("listings.csv")

# %%
df
# Out:
#              id                                               name    host_id  \
# 0          2015   Berlin-Mitte Value! Quiet courtyard/very central       2217
# 1          2695                 Prenzlauer Berg close to Mauerpark       2986
# 2          3176                    Fabulous Flat in great Location       3718
# 3          3309                  BerlinSpot Schöneberg near KaDeWe       4108
# 4          7071                   BrightRoom with sunny greenview!      17391
# ...         ...                                                ...        ...
# 22547  29856708       Cozy Apartment right in the center of Berlin   87555909
# 22548  29857108             Altbau/ Schöneberger Kiez / Schlafsofa   67537363
# 22549  29864272   Artists loft with garden in the center of Berlin    3146923
# 22550  29866805              Room for two with private shower / WC   36961901
# 22551  29867352  Sunny, modern and cozy flat in Berlin Neukölln :)  177464875
#
#         host_name     neighbourhood_group             neighbourhood  \
# 0             Ian                   Mitte           Brunnenstr. Süd
# 1         Michael                  Pankow  Prenzlauer Berg Nordwest
# 2          Britta                  Pankow   Prenzlauer Berg Südwest
# 3            Jana  Tempelhof - Schöneberg           Schöneberg-Nord
# 4          Bright                  Pankow            Helmholtzplatz
# ...           ...                     ...                       ...
# 22547     Ulisses                   Mitte           Brunnenstr. Süd
# 22548        Jörg  Tempelhof - Schöneberg           Schöneberg-Nord
# 22549      Martin                  Pankow   Prenzlauer Berg Südwest
# 22550  Arte Luise                   Mitte            Alexanderplatz
# 22551   Sebastian                Neukölln         Schillerpromenade
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      52.534537  13.402557  Entire home/apt     60               4
# 1      52.548513  13.404553     Private room     17               2
# 2      52.534996  13.417579  Entire home/apt     90              62
# 3      52.498855  13.349065     Private room     26               5
# 4      52.543157  13.415091     Private room     42               2
# ...          ...        ...              ...    ...             ...
# 22547  52.533865  13.400731  Entire home/apt     60               2
# 22548  52.496211  13.341738      Shared room     20               1
# 22549  52.531800  13.411999  Entire home/apt     85               3
# 22550  52.520802  13.378688     Private room     99               1
# 22551  52.473762  13.424447     Private room     45               5
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                    118  2018-10-28               3.76
# 1                      6  2018-10-01               1.42
# 2                    143  2017-03-20               1.25
# 3                     25  2018-08-16               0.39
# 4                    197  2018-11-04               1.75
# ...                  ...         ...                ...
# 22547                  0         NaN                NaN
# 22548                  0         NaN                NaN
# 22549                  0         NaN                NaN
# 22550                  0         NaN                NaN
# 22551                  0         NaN                NaN
#
#        calculated_host_listings_count  availability_365
# 0                                   4               141
# 1                                   1                 0
# 2                                   1               220
# 3                                   1               297
# 4                                   1                26
# ...                               ...               ...
# 22547                               1               314
# 22548                               6                78
# 22549                               2                15
# 22550                               3                 6
# 22551                               1                21
#
# [22552 rows x 16 columns]

# %% [markdown]
# Let's learn the various methods to grab data from a DataFrame

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
df['neighbourhood_group']
# Out:
# 0                         Mitte
# 1                        Pankow
# 2                        Pankow
# 3        Tempelhof - Schöneberg
# 4                        Pankow
#                   ...
# 22547                     Mitte
# 22548    Tempelhof - Schöneberg
# 22549                    Pankow
# 22550                     Mitte
# 22551                  Neukölln
# Name: neighbourhood_group, Length: 22552, dtype: object

# %%
df[['host_name', 'availability_365']]
# Out:
#         host_name  availability_365
# 0             Ian               141
# 1         Michael                 0
# 2          Britta               220
# 3            Jana               297
# 4          Bright                26
# ...           ...               ...
# 22547     Ulisses               314
# 22548        Jörg                78
# 22549      Martin                15
# 22550  Arte Luise                 6
# 22551   Sebastian                21
#
# [22552 rows x 2 columns]

# %% [markdown]
# Creating a new column

# %%
df['profit'] = df['price'] + df['minimum_nights']
df
# Out:
#              id                                               name    host_id  \
# 0          2015   Berlin-Mitte Value! Quiet courtyard/very central       2217
# 1          2695                 Prenzlauer Berg close to Mauerpark       2986
# 2          3176                    Fabulous Flat in great Location       3718
# 3          3309                  BerlinSpot Schöneberg near KaDeWe       4108
# 4          7071                   BrightRoom with sunny greenview!      17391
# ...         ...                                                ...        ...
# 22547  29856708       Cozy Apartment right in the center of Berlin   87555909
# 22548  29857108             Altbau/ Schöneberger Kiez / Schlafsofa   67537363
# 22549  29864272   Artists loft with garden in the center of Berlin    3146923
# 22550  29866805              Room for two with private shower / WC   36961901
# 22551  29867352  Sunny, modern and cozy flat in Berlin Neukölln :)  177464875
#
#         host_name     neighbourhood_group             neighbourhood  \
# 0             Ian                   Mitte           Brunnenstr. Süd
# 1         Michael                  Pankow  Prenzlauer Berg Nordwest
# 2          Britta                  Pankow   Prenzlauer Berg Südwest
# 3            Jana  Tempelhof - Schöneberg           Schöneberg-Nord
# 4          Bright                  Pankow            Helmholtzplatz
# ...           ...                     ...                       ...
# 22547     Ulisses                   Mitte           Brunnenstr. Süd
# 22548        Jörg  Tempelhof - Schöneberg           Schöneberg-Nord
# 22549      Martin                  Pankow   Prenzlauer Berg Südwest
# 22550  Arte Luise                   Mitte            Alexanderplatz
# 22551   Sebastian                Neukölln         Schillerpromenade
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      52.534537  13.402557  Entire home/apt     60               4
# 1      52.548513  13.404553     Private room     17               2
# 2      52.534996  13.417579  Entire home/apt     90              62
# 3      52.498855  13.349065     Private room     26               5
# 4      52.543157  13.415091     Private room     42               2
# ...          ...        ...              ...    ...             ...
# 22547  52.533865  13.400731  Entire home/apt     60               2
# 22548  52.496211  13.341738      Shared room     20               1
# 22549  52.531800  13.411999  Entire home/apt     85               3
# 22550  52.520802  13.378688     Private room     99               1
# 22551  52.473762  13.424447     Private room     45               5
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                    118  2018-10-28               3.76
# 1                      6  2018-10-01               1.42
# 2                    143  2017-03-20               1.25
# 3                     25  2018-08-16               0.39
# 4                    197  2018-11-04               1.75
# ...                  ...         ...                ...
# 22547                  0         NaN                NaN
# 22548                  0         NaN                NaN
# 22549                  0         NaN                NaN
# 22550                  0         NaN                NaN
# 22551                  0         NaN                NaN
#
#        calculated_host_listings_count  availability_365  profit
# 0                                   4               141      64
# 1                                   1                 0      19
# 2                                   1               220     152
# 3                                   1               297      31
# 4                                   1                26      44
# ...                               ...               ...     ...
# 22547                               1               314      62
# 22548                               6                78      21
# 22549                               2                15      88
# 22550                               3                 6     100
# 22551                               1                21      50
#
# [22552 rows x 17 columns]

# %% [markdown]
# Drop a column

# %%
df.drop('profit', axis=1, inplace=True)

# %%
df
# Out:
#              id                                               name    host_id  \
# 0          2015   Berlin-Mitte Value! Quiet courtyard/very central       2217
# 1          2695                 Prenzlauer Berg close to Mauerpark       2986
# 2          3176                    Fabulous Flat in great Location       3718
# 3          3309                  BerlinSpot Schöneberg near KaDeWe       4108
# 4          7071                   BrightRoom with sunny greenview!      17391
# ...         ...                                                ...        ...
# 22547  29856708       Cozy Apartment right in the center of Berlin   87555909
# 22548  29857108             Altbau/ Schöneberger Kiez / Schlafsofa   67537363
# 22549  29864272   Artists loft with garden in the center of Berlin    3146923
# 22550  29866805              Room for two with private shower / WC   36961901
# 22551  29867352  Sunny, modern and cozy flat in Berlin Neukölln :)  177464875
#
#         host_name     neighbourhood_group             neighbourhood  \
# 0             Ian                   Mitte           Brunnenstr. Süd
# 1         Michael                  Pankow  Prenzlauer Berg Nordwest
# 2          Britta                  Pankow   Prenzlauer Berg Südwest
# 3            Jana  Tempelhof - Schöneberg           Schöneberg-Nord
# 4          Bright                  Pankow            Helmholtzplatz
# ...           ...                     ...                       ...
# 22547     Ulisses                   Mitte           Brunnenstr. Süd
# 22548        Jörg  Tempelhof - Schöneberg           Schöneberg-Nord
# 22549      Martin                  Pankow   Prenzlauer Berg Südwest
# 22550  Arte Luise                   Mitte            Alexanderplatz
# 22551   Sebastian                Neukölln         Schillerpromenade
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      52.534537  13.402557  Entire home/apt     60               4
# 1      52.548513  13.404553     Private room     17               2
# 2      52.534996  13.417579  Entire home/apt     90              62
# 3      52.498855  13.349065     Private room     26               5
# 4      52.543157  13.415091     Private room     42               2
# ...          ...        ...              ...    ...             ...
# 22547  52.533865  13.400731  Entire home/apt     60               2
# 22548  52.496211  13.341738      Shared room     20               1
# 22549  52.531800  13.411999  Entire home/apt     85               3
# 22550  52.520802  13.378688     Private room     99               1
# 22551  52.473762  13.424447     Private room     45               5
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                    118  2018-10-28               3.76
# 1                      6  2018-10-01               1.42
# 2                    143  2017-03-20               1.25
# 3                     25  2018-08-16               0.39
# 4                    197  2018-11-04               1.75
# ...                  ...         ...                ...
# 22547                  0         NaN                NaN
# 22548                  0         NaN                NaN
# 22549                  0         NaN                NaN
# 22550                  0         NaN                NaN
# 22551                  0         NaN                NaN
#
#        calculated_host_listings_count  availability_365
# 0                                   4               141
# 1                                   1                 0
# 2                                   1               220
# 3                                   1               297
# 4                                   1                26
# ...                               ...               ...
# 22547                               1               314
# 22548                               6                78
# 22549                               2                15
# 22550                               3                 6
# 22551                               1                21
#
# [22552 rows x 16 columns]

# %% [markdown]
# Drop a row too

# %%
df.drop([2],axis=0)
# Out:
#              id                                               name    host_id  \
# 0          2015   Berlin-Mitte Value! Quiet courtyard/very central       2217
# 1          2695                 Prenzlauer Berg close to Mauerpark       2986
# 3          3309                  BerlinSpot Schöneberg near KaDeWe       4108
# 4          7071                   BrightRoom with sunny greenview!      17391
# 5          9991                Geourgeous flat - outstanding views      33852
# ...         ...                                                ...        ...
# 22547  29856708       Cozy Apartment right in the center of Berlin   87555909
# 22548  29857108             Altbau/ Schöneberger Kiez / Schlafsofa   67537363
# 22549  29864272   Artists loft with garden in the center of Berlin    3146923
# 22550  29866805              Room for two with private shower / WC   36961901
# 22551  29867352  Sunny, modern and cozy flat in Berlin Neukölln :)  177464875
#
#         host_name     neighbourhood_group             neighbourhood  \
# 0             Ian                   Mitte           Brunnenstr. Süd
# 1         Michael                  Pankow  Prenzlauer Berg Nordwest
# 3            Jana  Tempelhof - Schöneberg           Schöneberg-Nord
# 4          Bright                  Pankow            Helmholtzplatz
# 5         Philipp                  Pankow   Prenzlauer Berg Südwest
# ...           ...                     ...                       ...
# 22547     Ulisses                   Mitte           Brunnenstr. Süd
# 22548        Jörg  Tempelhof - Schöneberg           Schöneberg-Nord
# 22549      Martin                  Pankow   Prenzlauer Berg Südwest
# 22550  Arte Luise                   Mitte            Alexanderplatz
# 22551   Sebastian                Neukölln         Schillerpromenade
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      52.534537  13.402557  Entire home/apt     60               4
# 1      52.548513  13.404553     Private room     17               2
# 3      52.498855  13.349065     Private room     26               5
# 4      52.543157  13.415091     Private room     42               2
# 5      52.533031  13.416047  Entire home/apt    180               6
# ...          ...        ...              ...    ...             ...
# 22547  52.533865  13.400731  Entire home/apt     60               2
# 22548  52.496211  13.341738      Shared room     20               1
# 22549  52.531800  13.411999  Entire home/apt     85               3
# 22550  52.520802  13.378688     Private room     99               1
# 22551  52.473762  13.424447     Private room     45               5
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                    118  2018-10-28               3.76
# 1                      6  2018-10-01               1.42
# 3                     25  2018-08-16               0.39
# 4                    197  2018-11-04               1.75
# 5                      6  2018-07-23               0.15
# ...                  ...         ...                ...
# 22547                  0         NaN                NaN
# 22548                  0         NaN                NaN
# 22549                  0         NaN                NaN
# 22550                  0         NaN                NaN
# 22551                  0         NaN                NaN
#
#        calculated_host_listings_count  availability_365
# 0                                   4               141
# 1                                   1                 0
# 3                                   1               297
# 4                                   1                26
# 5                                   1               137
# ...                               ...               ...
# 22547                               1               314
# 22548                               6                78
# 22549                               2                15
# 22550                               3                 6
# 22551                               1                21
#
# [22551 rows x 16 columns]

# %% [markdown]
# Selecting a row

# %%
df.loc[[1]]
# Out:
#      id                                name  host_id host_name  \
# 1  2695  Prenzlauer Berg close to Mauerpark     2986   Michael
#
#   neighbourhood_group             neighbourhood   latitude  longitude  \
# 1              Pankow  Prenzlauer Berg Nordwest  52.548513  13.404553
#
#       room_type  price  minimum_nights  number_of_reviews last_review  \
# 1  Private room     17               2                  6  2018-10-01
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 1               1.42                               1                 0

# %%
df.iloc[1]
# Out:
# id                                                              2695
# name                              Prenzlauer Berg close to Mauerpark
# host_id                                                         2986
# host_name                                                    Michael
# neighbourhood_group                                           Pankow
# neighbourhood                               Prenzlauer Berg Nordwest
# latitude                                                   52.548513
# longitude                                                  13.404553
# room_type                                               Private room
# price                                                             17
# minimum_nights                                                     2
# number_of_reviews                                                  6
# last_review                                               2018-10-01
# reviews_per_month                                               1.42
# calculated_host_listings_count                                     1
# availability_365                                                   0
# Name: 1, dtype: object

# %% [markdown]
# Selecting a subset

# %%
df.loc[[1], 'price']
# Out:
# 1    17
# Name: price, dtype: int64

# %% [markdown]
# Dealing with missing values

# %%
df.isnull().sum()
# Out:
# id                                   0
# name                                59
# host_id                              0
# host_name                           26
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       3908
# reviews_per_month                 3914
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %%
df.dropna()
# Out:
#              id                                               name    host_id  \
# 0          2015   Berlin-Mitte Value! Quiet courtyard/very central       2217
# 1          2695                 Prenzlauer Berg close to Mauerpark       2986
# 2          3176                    Fabulous Flat in great Location       3718
# 3          3309                  BerlinSpot Schöneberg near KaDeWe       4108
# 4          7071                   BrightRoom with sunny greenview!      17391
# ...         ...                                                ...        ...
# 22449  29772631                 Cosy and lovely room near Ostkreuz   20727291
# 22463  29784461     House on the water HT10 - Heart of East Berlin   22437698
# 22475  29792124                         Welcome to Light Apartment  224133729
# 22508  29817383                                     Prenzlauerberg  224295751
# 22536  29849565  Super zentrales Apartment + Garten für 6 Personen     607481
#
#        host_name       neighbourhood_group             neighbourhood  \
# 0            Ian                     Mitte           Brunnenstr. Süd
# 1        Michael                    Pankow  Prenzlauer Berg Nordwest
# 2         Britta                    Pankow   Prenzlauer Berg Südwest
# 3           Jana    Tempelhof - Schöneberg           Schöneberg-Nord
# 4         Bright                    Pankow            Helmholtzplatz
# ...          ...                       ...                       ...
# 22449       Anna               Lichtenberg           Neu Lichtenberg
# 22463  Sebastian        Treptow - Köpenick           Oberschöneweide
# 22475       Inna  Friedrichshain-Kreuzberg  Frankfurter Allee Süd FK
# 22508      Salem                    Pankow  Prenzlauer Berg Nordwest
# 22536       Sven                    Pankow   Prenzlauer Berg Südwest
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      52.534537  13.402557  Entire home/apt     60               4
# 1      52.548513  13.404553     Private room     17               2
# 2      52.534996  13.417579  Entire home/apt     90              62
# 3      52.498855  13.349065     Private room     26               5
# 4      52.543157  13.415091     Private room     42               2
# ...          ...        ...              ...    ...             ...
# 22449  52.502952  13.490870     Private room     25               2
# 22463  52.457982  13.526945  Entire home/apt     99               1
# 22475  52.507884  13.467071     Private room     25               1
# 22508  52.552250  13.410904  Entire home/apt     70               1
# 22536  52.536666  13.411360  Entire home/apt    150              10
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                    118  2018-10-28               3.76
# 1                      6  2018-10-01               1.42
# 2                    143  2017-03-20               1.25
# 3                     25  2018-08-16               0.39
# 4                    197  2018-11-04               1.75
# ...                  ...         ...                ...
# 22449                  1  2018-11-04               1.00
# 22463                  5  2018-11-06               5.00
# 22475                  1  2018-11-05               1.00
# 22508                  1  2018-11-07               1.00
# 22536                  2  2018-11-07               2.00
#
#        calculated_host_listings_count  availability_365
# 0                                   4               141
# 1                                   1                 0
# 2                                   1               220
# 3                                   1               297
# 4                                   1                26
# ...                               ...               ...
# 22449                               1                32
# 22463                               2               339
# 22475                               1                 8
# 22508                               1               350
# 22536                               1                69
#
# [18587 rows x 16 columns]

# %%
df.dropna(axis=1)
# Out:
#              id    host_id     neighbourhood_group             neighbourhood  \
# 0          2015       2217                   Mitte           Brunnenstr. Süd
# 1          2695       2986                  Pankow  Prenzlauer Berg Nordwest
# 2          3176       3718                  Pankow   Prenzlauer Berg Südwest
# 3          3309       4108  Tempelhof - Schöneberg           Schöneberg-Nord
# 4          7071      17391                  Pankow            Helmholtzplatz
# ...         ...        ...                     ...                       ...
# 22547  29856708   87555909                   Mitte           Brunnenstr. Süd
# 22548  29857108   67537363  Tempelhof - Schöneberg           Schöneberg-Nord
# 22549  29864272    3146923                  Pankow   Prenzlauer Berg Südwest
# 22550  29866805   36961901                   Mitte            Alexanderplatz
# 22551  29867352  177464875                Neukölln         Schillerpromenade
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      52.534537  13.402557  Entire home/apt     60               4
# 1      52.548513  13.404553     Private room     17               2
# 2      52.534996  13.417579  Entire home/apt     90              62
# 3      52.498855  13.349065     Private room     26               5
# 4      52.543157  13.415091     Private room     42               2
# ...          ...        ...              ...    ...             ...
# 22547  52.533865  13.400731  Entire home/apt     60               2
# 22548  52.496211  13.341738      Shared room     20               1
# 22549  52.531800  13.411999  Entire home/apt     85               3
# 22550  52.520802  13.378688     Private room     99               1
# 22551  52.473762  13.424447     Private room     45               5
#
#        number_of_reviews  calculated_host_listings_count  availability_365
# 0                    118                               4               141
# 1                      6                               1                 0
# 2                    143                               1               220
# 3                     25                               1               297
# 4                    197                               1                26
# ...                  ...                             ...               ...
# 22547                  0                               1               314
# 22548                  0                               6                78
# 22549                  0                               2                15
# 22550                  0                               3                 6
# 22551                  0                               1                21
#
# [22552 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# id                                   0
# name                                59
# host_id                              0
# host_name                           26
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       3908
# reviews_per_month                 3914
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %%
df['reviews_per_month'].fillna((df['reviews_per_month'].mean()), inplace=True)
df
# Out:
#              id                                               name    host_id  \
# 0          2015   Berlin-Mitte Value! Quiet courtyard/very central       2217
# 1          2695                 Prenzlauer Berg close to Mauerpark       2986
# 2          3176                    Fabulous Flat in great Location       3718
# 3          3309                  BerlinSpot Schöneberg near KaDeWe       4108
# 4          7071                   BrightRoom with sunny greenview!      17391
# ...         ...                                                ...        ...
# 22547  29856708       Cozy Apartment right in the center of Berlin   87555909
# 22548  29857108             Altbau/ Schöneberger Kiez / Schlafsofa   67537363
# 22549  29864272   Artists loft with garden in the center of Berlin    3146923
# 22550  29866805              Room for two with private shower / WC   36961901
# 22551  29867352  Sunny, modern and cozy flat in Berlin Neukölln :)  177464875
#
#         host_name     neighbourhood_group             neighbourhood  \
# 0             Ian                   Mitte           Brunnenstr. Süd
# 1         Michael                  Pankow  Prenzlauer Berg Nordwest
# 2          Britta                  Pankow   Prenzlauer Berg Südwest
# 3            Jana  Tempelhof - Schöneberg           Schöneberg-Nord
# 4          Bright                  Pankow            Helmholtzplatz
# ...           ...                     ...                       ...
# 22547     Ulisses                   Mitte           Brunnenstr. Süd
# 22548        Jörg  Tempelhof - Schöneberg           Schöneberg-Nord
# 22549      Martin                  Pankow   Prenzlauer Berg Südwest
# 22550  Arte Luise                   Mitte            Alexanderplatz
# 22551   Sebastian                Neukölln         Schillerpromenade
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      52.534537  13.402557  Entire home/apt     60               4
# 1      52.548513  13.404553     Private room     17               2
# 2      52.534996  13.417579  Entire home/apt     90              62
# 3      52.498855  13.349065     Private room     26               5
# 4      52.543157  13.415091     Private room     42               2
# ...          ...        ...              ...    ...             ...
# 22547  52.533865  13.400731  Entire home/apt     60               2
# 22548  52.496211  13.341738      Shared room     20               1
# 22549  52.531800  13.411999  Entire home/apt     85               3
# 22550  52.520802  13.378688     Private room     99               1
# 22551  52.473762  13.424447     Private room     45               5
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                    118  2018-10-28           3.760000
# 1                      6  2018-10-01           1.420000
# 2                    143  2017-03-20           1.250000
# 3                     25  2018-08-16           0.390000
# 4                    197  2018-11-04           1.750000
# ...                  ...         ...                ...
# 22547                  0         NaN           1.135525
# 22548                  0         NaN           1.135525
# 22549                  0         NaN           1.135525
# 22550                  0         NaN           1.135525
# 22551                  0         NaN           1.135525
#
#        calculated_host_listings_count  availability_365
# 0                                   4               141
# 1                                   1                 0
# 2                                   1               220
# 3                                   1               297
# 4                                   1                26
# ...                               ...               ...
# 22547                               1               314
# 22548                               6                78
# 22549                               2                15
# 22550                               3                 6
# 22551                               1                21
#
# [22552 rows x 16 columns]

# %% [markdown]
# removing rows with NaN values, 'name'

# %%
df.dropna(subset=['name'], axis=0, inplace=True)

df.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                           26
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       3885
# reviews_per_month                    0
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  2.249300e+04  2.249300e+04  22493.000000  22493.000000  22493.000000
# mean   1.573362e+07  5.408507e+07     52.509836     13.406092     66.970480
# std    8.553788e+06  5.821806e+07      0.030833      0.058004    218.078376
# min    2.015000e+03  2.217000e+03     52.345803     13.103557      0.000000
# 25%    8.087198e+06  9.228021e+06     52.489088     13.375403     30.000000
# 50%    1.692280e+07  3.123294e+07     52.509086     13.416756     45.000000
# 75%    2.259922e+07  8.083775e+07     52.532670     13.439273     70.000000
# max    2.986735e+07  2.245081e+08     52.651670     13.757642   9000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    22493.000000       22493.000000       22493.000000
# mean         7.166763          17.879162           1.137090
# std         40.717403          36.805939           1.371189
# min          1.000000           0.000000           0.010000
# 25%          2.000000           1.000000           0.220000
# 50%          2.000000           5.000000           0.840000
# 75%          4.000000          16.000000           1.180000
# max       5000.000000         498.000000          36.670000
#
#        calculated_host_listings_count  availability_365
# count                    22493.000000      22493.000000
# mean                         1.920331         80.000800
# std                          3.671773        119.408255
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000          4.000000
# 75%                          1.000000        129.000000
# max                         45.000000        365.000000

# %%
df.cov()
# Out:
#                                           id       host_id      latitude  \
# id                              7.316730e+13  2.626595e+14   1487.341835
# host_id                         2.626595e+14  3.389342e+15  12434.660101
# latitude                        1.487342e+03  1.243466e+04      0.000951
# longitude                      -9.040752e+03 -1.583495e+05     -0.000191
# price                           5.670099e+07  4.765268e+08      0.006418
# minimum_nights                 -1.463175e+07 -6.746983e+07      0.014933
# number_of_reviews              -9.764701e+07 -3.193058e+08      0.043015
# reviews_per_month               2.633192e+06  1.432919e+07      0.001622
# calculated_host_listings_count  1.188158e+06 -1.042688e+07      0.004496
# availability_365               -6.191545e+07 -6.779264e+07      0.043053
#
#                                     longitude         price  minimum_nights  \
# id                               -9040.752469  5.670099e+07   -1.463175e+07
# host_id                        -158349.450251  4.765268e+08   -6.746983e+07
# latitude                            -0.000191  6.417736e-03    1.493271e-02
# longitude                            0.003364 -5.477766e-01   -6.246841e-02
# price                               -0.547777  4.755818e+04    3.356352e+01
# minimum_nights                      -0.062468  3.356352e+01    1.657907e+03
# number_of_reviews                   -0.044463 -6.688655e+00   -3.264422e+01
# reviews_per_month                   -0.002981  1.972645e+00   -2.557008e+00
# calculated_host_listings_count      -0.009385  5.948858e+01    4.072463e+00
# availability_365                    -0.600313  2.740176e+03    4.829997e+02
#
#                                 number_of_reviews  reviews_per_month  \
# id                                  -9.764701e+07       2.633192e+06
# host_id                             -3.193058e+08       1.432919e+07
# latitude                             4.301507e-02       1.621878e-03
# longitude                           -4.446331e-02      -2.980941e-03
# price                               -6.688655e+00       1.972645e+00
# minimum_nights                      -3.264422e+01      -2.557008e+00
# number_of_reviews                    1.354677e+03       2.738538e+01
# reviews_per_month                    2.738538e+01       1.880159e+00
# calculated_host_listings_count       1.158312e+01       5.686162e-01
# availability_365                     1.218342e+03       3.487641e+01
#
#                                 calculated_host_listings_count  \
# id                                                1.188158e+06
# host_id                                          -1.042688e+07
# latitude                                          4.496017e-03
# longitude                                        -9.384925e-03
# price                                             5.948858e+01
# minimum_nights                                    4.072463e+00
# number_of_reviews                                 1.158312e+01
# reviews_per_month                                 5.686162e-01
# calculated_host_listings_count                    1.348192e+01
# availability_365                                  1.106737e+02
#
#                                 availability_365
# id                                 -6.191545e+07
# host_id                            -6.779264e+07
# latitude                            4.305329e-02
# longitude                          -6.003128e-01
# price                               2.740176e+03
# minimum_nights                      4.829997e+02
# number_of_reviews                   1.218342e+03
# reviews_per_month                   3.487641e+01
# calculated_host_listings_count      1.106737e+02
# availability_365                    1.425833e+04

# %%
df.corr()
# Out:
#                                       id   host_id  latitude  longitude  \
# id                              1.000000  0.527445  0.005639  -0.018222
# host_id                         0.527445  1.000000  0.006927  -0.046892
# latitude                        0.005639  0.006927  1.000000  -0.106846
# longitude                      -0.018222 -0.046892 -0.106846   1.000000
# price                           0.030396  0.037533  0.000954  -0.043304
# minimum_nights                 -0.042010 -0.028462  0.011894  -0.026450
# number_of_reviews              -0.310158 -0.149015  0.037904  -0.020827
# reviews_per_month               0.224505  0.179501  0.038362  -0.037480
# calculated_host_listings_count  0.037830 -0.048778  0.039713  -0.044065
# availability_365               -0.060619 -0.009752  0.011694  -0.086673
#
#                                    price  minimum_nights  number_of_reviews  \
# id                              0.030396       -0.042010          -0.310158
# host_id                         0.037533       -0.028462          -0.149015
# latitude                        0.000954        0.011894           0.037904
# longitude                      -0.043304       -0.026450          -0.020827
# price                           1.000000        0.003780          -0.000833
# minimum_nights                  0.003780        1.000000          -0.021783
# number_of_reviews              -0.000833       -0.021783           1.000000
# reviews_per_month               0.006597       -0.045799           0.542630
# calculated_host_listings_count  0.074293        0.027240           0.085710
# availability_365                0.105228        0.099342           0.277215
#
#                                 reviews_per_month  \
# id                                       0.224505
# host_id                                  0.179501
# latitude                                 0.038362
# longitude                               -0.037480
# price                                    0.006597
# minimum_nights                          -0.045799
# number_of_reviews                        0.542630
# reviews_per_month                        1.000000
# calculated_host_listings_count           0.112940
# availability_365                         0.213010
#
#                                 calculated_host_listings_count  \
# id                                                    0.037830
# host_id                                              -0.048778
# latitude                                              0.039713
# longitude                                            -0.044065
# price                                                 0.074293
# minimum_nights                                        0.027240
# number_of_reviews                                     0.085710
# reviews_per_month                                     0.112940
# calculated_host_listings_count                        1.000000
# availability_365                                      0.252426
#
#                                 availability_365
# id                                     -0.060619
# host_id                                -0.009752
# latitude                                0.011694
# longitude                              -0.086673
# price                                   0.105228
# minimum_nights                          0.099342
# number_of_reviews                       0.277215
# reviews_per_month                       0.213010
# calculated_host_listings_count          0.252426
# availability_365                        1.000000
