# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
sentence = "He's a German Shephard. They are some of the smartest dogs!"
word_tokenize(sentence)
# Out:
# ['He',
#  "'s",
#  'a',
#  'German',
#  'Shephard',
#  '.',
#  'They',
#  'are',
#  'some',
#  'of',
#  'the',
#  'smartest',
#  'dogs',
#  '!']

# %%
article = ''' The covid situation is getter better? Not everyone is getting vaccinated. You should still wear a mask!'''

# %%
from nltk.tokenize import sent_tokenize

# %%
sent_tokenize(article)
# Out:
# [' The covid situation is getter better?',
#  'Not everyone is getting vaccinated.',
#  'You should still wear a mask!']

# %% [markdown]
# Regular Expression

# %%
import re

# %%
test_corpus = re.split('\W+', sentence)
print(test_corpus)
# Out:
# ['He', 's', 'a', 'German', 'Shephard', 'They', 'are', 'some', 'of', 'the', 'smartest', 'dogs', '']

# %%
string = 'one and two and three and four and five'
result = re.sub(' ','-',string)
print(result)
# Out:
# one-and-two-and-three-and-four-and-five

# %% [markdown]
# Stemming and Lemmatization

# %%
from nltk.stem.porter import PorterStemmer

# %%
ps = PorterStemmer()
print(ps.stem('bundles'))
# Out:
# 'bundl'

# %%
print(ps.stem('jumping'))
# Out:
# 'jump'

# %%
print(ps.stem('spies'))
# Out:
# spi

# %%
nltk.download('wordnet')
from nltk.stem import wordnet
from nltk.stem import WordNetLemmatizer
word_lem = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
print(word_lem.lemmatize('spies'))
# Out:
# spy

# %% [markdown]
# Importing the Dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/IST347/Week_14/Restaurant_Reviews.tsv', delimiter='\t', quoting=3)

# %%
df.shape
# Out:
# (1000, 2)
